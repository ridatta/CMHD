# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
data = np.loadtxt("bound.txt")
plt.imshow(data,vmin=0,vmax=1)

# %%
data = np.loadtxt("rho-0.txt")
plt.imshow(data,vmin=0,vmax=1)

# %%
data = np.loadtxt("p.txt")
plt.imshow(data)

# %%
data = np.loadtxt("rho.txt")
plt.imshow(data,vmin=0)
